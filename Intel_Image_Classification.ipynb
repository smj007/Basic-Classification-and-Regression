# %%
import tensorflow as tf

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 17991999302346215254
# , name: "/device:XLA_CPU:0"
# device_type: "XLA_CPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 8745045479332939857
# physical_device_desc: "device: XLA_CPU device"
# , name: "/device:XLA_GPU:0"
# device_type: "XLA_GPU"
# memory_limit: 17179869184
# locality {
# }
# incarnation: 12337103857988043829
# physical_device_desc: "device: XLA_GPU device"
# , name: "/device:GPU:0"
# device_type: "GPU"
# memory_limit: 11150541440
# locality {
#   bus_id: 1
#   links {
#   }
# }
# incarnation: 3386287429866332857
# physical_device_desc: "device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7"
# ]

# %%
import tensorflow.keras.layers as Layers
import tensorflow.keras.activations as Activations
import tensorflow.keras.models as Models
import tensorflow.keras.optimizers as Optimizer
import tensorflow.keras.metrics as Metrics
import tensorflow.keras.utils as Utils
from keras.utils.vis_utils import model_to_dot
import os
import matplotlib.pyplot as plot
import cv2
import numpy as np
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix as CM
from random import randint
from IPython.display import SVG
import matplotlib.gridspec as gridspec
# Out:
# Using TensorFlow backend.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
os.chdir('drive/My Drive/')

# %%
def get_images(directory):
    
    Images = []
    Labels = []
    label = 0
    
    for labels in os.listdir(directory):
        if labels == 'buildings':
            label = 0
        elif labels == 'forest':
            label= 1
        elif labels == 'glacier':
            label = 2
        elif labels == 'mountain':
            label = 3
        elif labels == 'sea':
            label = 4
        elif labels == 'street':
            label = 5
            
        for image_file in os.listdir(directory + labels):
            image = cv2.imread(directory + labels + r'/' + image_file)
            image = cv2.resize(image, (150, 150))
            Images.append(image)
            Labels.append(label)
            
    return shuffle(Images, Labels, random_state = 123)

def get_classlabel(code):
    
    labels = {0 : 'buildings',
             1: 'forest',
             2: 'glacier',
             3: 'mountain',
             4: 'sea',
             5: 'street'}
    return labels[code]

# %%
Images, Labels = get_images('intel/seg_train/')
Images = np.array(Images)
Labels = np.array(Labels)

# %%
print("Images shape: ", Images.shape)
print("Labels shape", Labels.shape)
# Out:
# Images shape:  (14034, 150, 150, 3)
# Labels shape (14034,)

# %%
f, ax = plot.subplots(5, 5)
f.subplots_adjust(0, 0, 3, 3)
for i in range(0, 5):
    for j in range(0, 5):
        rand = randint(0, len(Images))
        ax[i, j].imshow(Images[rand])
        ax[i, j].set_title(get_classlabel(Labels[rand]))

# %%
model = Models.Sequential()

model.add(Layers.Conv2D(200,kernel_size=(3,3),activation='relu',input_shape=(150,150,3)))
model.add(Layers.Conv2D(180,kernel_size=(3,3),activation='relu'))
model.add(Layers.MaxPool2D(5,5))
model.add(Layers.Conv2D(180,kernel_size=(3,3),activation='relu'))
model.add(Layers.Conv2D(140,kernel_size=(3,3),activation='relu'))
model.add(Layers.Conv2D(100,kernel_size=(3,3),activation='relu'))
model.add(Layers.Conv2D(50,kernel_size=(3,3),activation='relu'))
model.add(Layers.MaxPool2D(5,5))
model.add(Layers.Flatten())
model.add(Layers.Dense(180,activation='relu'))
model.add(Layers.Dense(100,activation='relu'))
model.add(Layers.Dense(50,activation='relu'))
model.add(Layers.Dropout(rate=0.5))
model.add(Layers.Dense(6,activation='softmax'))

model.compile(optimizer=Optimizer.Adam(lr=0.0001),loss='sparse_categorical_crossentropy',metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 200)     5600
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 146, 146, 180)     324180
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 29, 29, 180)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 27, 27, 180)       291780
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 25, 25, 140)       226940
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 23, 23, 100)       126100
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 21, 21, 50)        45050
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 50)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 800)               0
# _________________________________________________________________
# dense (Dense)                (None, 180)               144180
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               18100
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dropout (Dropout)            (None, 50)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 306
# =================================================================
# Total params: 1,187,286
# Trainable params: 1,187,286
# Non-trainable params: 0
# _________________________________________________________________

# %%
trained = model.fit(Images,Labels,epochs=25,validation_split=0.30, batch_size = 64)
# Out:
# Epoch 1/25
# 154/154 [==============================] - 246s 2s/step - loss: 1.5137 - accuracy: 0.3875 - val_loss: 1.1096 - val_accuracy: 0.5744
# Epoch 2/25
# 154/154 [==============================] - 239s 2s/step - loss: 1.1773 - accuracy: 0.5430 - val_loss: 0.9971 - val_accuracy: 0.6464
# Epoch 3/25
# 154/154 [==============================] - 239s 2s/step - loss: 1.0073 - accuracy: 0.6282 - val_loss: 0.8670 - val_accuracy: 0.6796
# Epoch 4/25
# 154/154 [==============================] - 239s 2s/step - loss: 0.8941 - accuracy: 0.6715 - val_loss: 0.7966 - val_accuracy: 0.7108
# Epoch 5/25
# 154/154 [==============================] - 239s 2s/step - loss: 0.8000 - accuracy: 0.7157 - val_loss: 0.7068 - val_accuracy: 0.7393
# Epoch 6/25
# 154/154 [==============================] - 239s 2s/step - loss: 0.7389 - accuracy: 0.7371 - val_loss: 0.8316 - val_accuracy: 0.6963
# Epoch 7/25
# 154/154 [==============================] - 239s 2s/step - loss: 0.6936 - accuracy: 0.7578 - val_loss: 0.5735 - val_accuracy: 0.7943
# Epoch 8/25
# 154/154 [==============================] - 239s 2s/step - loss: 0.6497 - accuracy: 0.7746 - val_loss: 0.5704 - val_accuracy: 0.8038
# Epoch 9/25
# 154/154 [==============================] - 239s 2s/step - loss: 0.6035 - accuracy: 0.7901 - val_loss: 0.5603 - val_accuracy: 0.7960
# Epoch 10/25
# 154/154 [==============================] - 239s 2s/step - loss: 0.5755 - accuracy: 0.8019 - val_loss: 0.5445 - val_accuracy: 0.8003
# Epoch 11/25
# 154/154 [==============================] - 239s 2s/step - loss: 0.5218 - accuracy: 0.8176 - val_loss: 0.5443 - val_accuracy: 0.8150
# Epoch 12/25
# 154/154 [==============================] - 240s 2s/step - loss: 0.5049 - accuracy: 0.8291 - val_loss: 0.5504 - val_accuracy: 0.8202
# Epoch 13/25
# 154/154 [==============================] - 239s 2s/step - loss: 0.4758 - accuracy: 0.8374 - val_loss: 0.5091 - val_accuracy: 0.8169
# Epoch 14/25
# 154/154 [==============================] - 239s 2s/step - loss: 0.4603 - accuracy: 0.8448 - val_loss: 0.4921 - val_accuracy: 0.8357
# Epoch 15/25
# 154/154 [==============================] - 239s 2s/step - loss: 0.4419 - accuracy: 0.8520 - val_loss: 0.5510 - val_accuracy: 0.8112
# Epoch 16/25
# 154/154 [==============================] - 239s 2s/step - loss: 0.3813 - accuracy: 0.8711 - val_loss: 0.5344 - val_accuracy: 0.8247
# Epoch 17/25
# 154/154 [==============================] - 240s 2s/step - loss: 0.3820 - accuracy: 0.8708 - val_loss: 0.5307 - val_accuracy: 0.8257
# Epoch 18/25
# 154/154 [==============================] - 239s 2s/step - loss: 0.3468 - accuracy: 0.8836 - val_loss: 0.4978 - val_accuracy: 0.8347
# Epoch 19/25
# 154/154 [==============================] - 239s 2s/step - loss: 0.3336 - accuracy: 0.8876 - val_loss: 0.5421 - val_accuracy: 0.8328
# Epoch 20/25
# 154/154 [==============================] - 239s 2s/step - loss: 0.2941 - accuracy: 0.9040 - val_loss: 0.5025 - val_accuracy: 0.8445
# Epoch 21/25
# 154/154 [==============================] - 239s 2s/step - loss: 0.2801 - accuracy: 0.9047 - val_loss: 0.5462 - val_accuracy: 0.8319
# Epoch 22/25
# 154/154 [==============================] - 239s 2s/step - loss: 0.2480 - accuracy: 0.9149 - val_loss: 0.5740 - val_accuracy: 0.8430
# Epoch 23/25
# 154/154 [==============================] - 240s 2s/step - loss: 0.2158 - accuracy: 0.9282 - val_loss: 0.6137 - val_accuracy: 0.8399
# Epoch 24/25
# 154/154 [==============================] - 240s 2s/step - loss: 0.2083 - accuracy: 0.9295 - val_loss: 0.6035 - val_accuracy: 0.8380
# Epoch 25/25
# 154/154 [==============================] - 240s 2s/step - loss: 0.1966 - accuracy: 0.9339 - val_loss: 0.6199 - val_accuracy: 0.8288

# %%
plot.plot(trained.history['acc'])
plot.plot(trained.history['val_acc'])
plot.title('Model Accuracy')
plot.ylabel('Accuracy')
plot.xlabel('Epochs')
plot.legend(['Train', 'Test'], loc = 'upper left')
plot.show()

plot.plot(trained.history['loss'])
plot.plot(trained.history['val_loss'])
plot.title('Model Loss')
plot.xlabel('Epochs')
plot.ylabel('Loss')
plot.legend(['Train', 'Test'], loc = 'upper left')
plot.show()

# %%
test_images, test_labels = get_images('intel/seg_test/')
test_images = np.array(test_images)
test_labels = np.array(test_labels)
model.evaluate(test_images, test_labels, verbose = 1)
# Out:
# 94/94 [==============================] - 18s 188ms/step - loss: 0.5623 - accuracy: 0.8437
# [0.5623167753219604, 0.843666672706604]

# %%
pred_images, _ = get_images('intel/seg_pred/')
pred_images = np.array(pred_images)
pred_images.shape
# Out:
# (7301, 150, 150, 3)

# %%
#display the class label on top and then the image and after that display the probabilities of each class
fig = plot.figure(figsize = (30, 30))
outer = gridspec.GridSpec(5, 5, wspace = 0.2, hspace = 0.2)

fig = plot.figure(figsize=(30, 30))
outer = gridspec.GridSpec(5, 5, wspace=0.2, hspace=0.2)

for i in range(25):
    inner = gridspec.GridSpecFromSubplotSpec(2, 1,subplot_spec=outer[i], wspace=0.1, hspace=0.1)
    rnd_number = randint(0,len(pred_images))
    pred_image = np.array([pred_images[rnd_number]])
    pred_class = get_classlabel(model.predict_classes(pred_image)[0])
    pred_prob = model.predict(pred_image).reshape(6)
    for j in range(2):
        if (j%2) == 0:
            ax = plot.Subplot(fig, inner[j])
            ax.imshow(pred_image[0])
            ax.set_title(pred_class)
            ax.set_xticks([])
            ax.set_yticks([])
            fig.add_subplot(ax)
        else:
            ax = plot.Subplot(fig, inner[j])
            ax.bar([0,1,2,3,4,5],pred_prob)
            fig.add_subplot(ax)


fig.show()
# Out:
# WARNING:tensorflow:From <ipython-input-16-9f83a1b060da>:12: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
